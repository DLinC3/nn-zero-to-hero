# %% [markdown]
# Lecture 3: makemore Part 2 MLP
#
# Purpose: my local follow-along notebook for Lecture 3.
#
# Reminder: reproduce the official notebook/code locally, then summarize core intuition.
