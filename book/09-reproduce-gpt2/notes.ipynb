# %% [markdown]
# Lecture 9: Let's reproduce GPT-2 124M
#
# Purpose: my local follow-along notebook for Lecture 9.
#
# Reminder: reproduce the official notebook/code locally, then summarize core intuition.
