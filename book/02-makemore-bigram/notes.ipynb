# %% [markdown]
# Lecture 2: makemore Part 1 Bigram
#
# Purpose: my local follow-along notebook for Lecture 2.
#
# Reminder: reproduce the official notebook/code locally, then summarize core intuition.
