# %% [markdown]
# Lecture 4: makemore Part 3 BatchNorm
#
# Purpose: my local follow-along notebook for Lecture 4.
#
# Reminder: reproduce the official notebook/code locally, then summarize core intuition.
