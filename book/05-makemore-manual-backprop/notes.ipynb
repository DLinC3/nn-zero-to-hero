# %% [markdown]
# Lecture 5: makemore Part 4 Manual Backprop
#
# Purpose: my local follow-along notebook for Lecture 5.
#
# Reminder: reproduce the official notebook/code locally, then summarize core intuition.
