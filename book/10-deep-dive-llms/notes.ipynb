# %% [markdown]
# Lecture 10: Deep Dive into LLMs
#
# Purpose: my local follow-along notebook for Lecture 10.
#
# Reminder: reproduce the official notebook/code locally, then summarize core intuition.
