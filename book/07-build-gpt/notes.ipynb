# %% [markdown]
# Lecture 7: Let's build GPT
#
# Purpose: my local follow-along notebook for Lecture 7.
#
# Reminder: reproduce the official notebook/code locally, then summarize core intuition.
