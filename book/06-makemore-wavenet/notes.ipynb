# %% [markdown]
# Lecture 6: makemore Part 5 WaveNet
#
# Purpose: my local follow-along notebook for Lecture 6.
#
# Reminder: reproduce the official notebook/code locally, then summarize core intuition.
