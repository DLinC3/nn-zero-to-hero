# %% [markdown]
# Lecture 8: Let's build the GPT Tokenizer
#
# Purpose: my local follow-along notebook for Lecture 8.
#
# Reminder: reproduce the official notebook/code locally, then summarize core intuition.
